# %% [markdown]
# # SKAB Data Loader Scouting

# %%
from matplotlib import pyplot as plt
from os.path import join
from skab_factory.functions import load_data_from_dir

# %%
DATA_DIR = join("data", "other")
print(f"All data are loaded from {DATA_DIR}")
# Out:
# All data are loaded from data\other

# %% [markdown]
# ## Load the Data

# %%
data = load_data_from_dir(
    # Original arguments
    dir_name=DATA_DIR,

    # Args for pandas.read_csv()
    sep=";",
    parse_dates=[0],
    index_col=0
)

# %% [markdown]
# ## Visualize Columns of Data (using the first csv file as an Example)

# %%
for column in data.columns:
    plt.plot(data.loc[data.origin=="data\\other\\1.csv"][column], label=column)
    plt.legend(loc=0)
    plt.show()

# %% [markdown]
# ## Explore loaded Data

# %%
x_colums = [
    "Accelerometer1RMS",
    "Accelerometer2RMS",
    "Current",
    "Pressure",
    "Temperature",
    "Thermocouple",
    "Voltage",
    "Volume Flow RateRMS"
]

y_colums = [
    "anomaly"
]

X = data[x_colums]
y = data[y_colums]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14943 entries, 2020-03-01 15:44:06 to * **`14.csv`:** Water supply of increased temperature
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Accelerometer1RMS    14929 non-null  float64
#  1   Accelerometer2RMS    14929 non-null  float64
#  2   Current              14929 non-null  float64
#  3   Pressure             14929 non-null  float64
#  4   Temperature          14929 non-null  float64
#  5   Thermocouple         14929 non-null  float64
#  6   Voltage              14929 non-null  float64
#  7   Volume Flow RateRMS  14929 non-null  float64
#  8   anomaly              14929 non-null  float64
#  9   changepoint          14929 non-null  float64
#  10  origin               14943 non-null  object
# dtypes: float64(10), object(1)
# memory usage: 1.4+ MB

# %%
data.sort_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\GIT-Repository\skab_scouting\loading_data_other.ipynb Cell 10 line <module>
# ----> <a href='vscode-notebook-cell:/c%3A/GIT-Repository/skab_scouting/loading_data_other.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> data.sort_index()
#
# File c:\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Python\Python39\lib\site-packages\pandas\core\frame.py:6393, in DataFrame.sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    6291 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self"])
#    6292 def sort_index(
#    6293     self,
#    (...)
#    6302     key: IndexKeyFunc = None,
#    6303 ):
#    6304     """
#    6305     Sort object by labels (along an axis).
#    6306
#    (...)
#    6391     d  4
#    6392     """
# -> 6393     return super().sort_index(
#    6394         axis,
#    6395         level,
#    6396         ascending,
#    6397         inplace,
#    6398         kind,
#    6399         na_position,
#    6400         sort_remaining,
#    6401         ignore_index,
#    6402         key,
#    6403     )
#
# File c:\Python\Python39\lib\site-packages\pandas\core\generic.py:4544, in NDFrame.sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    4540 ascending = validate_ascending(ascending)
#    4542 target = self._get_axis(axis)
# -> 4544 indexer = get_indexer_indexer(
#    4545     target, level, ascending, kind, na_position, sort_remaining, key
#    4546 )
#    4548 if indexer is None:
#    4549     if inplace:
#
# File c:\Python\Python39\lib\site-packages\pandas\core\sorting.py:91, in get_indexer_indexer(target, level, ascending, kind, na_position, sort_remaining, key)
#      86     if (ascending and target.is_monotonic_increasing) or (
#      87         not ascending and target.is_monotonic_decreasing
#      88     ):
#      89         return None
# ---> 91     indexer = nargsort(
#      92         target, kind=kind, ascending=ascending, na_position=na_position
#      93     )
#      94 return indexer
#
# File c:\Python\Python39\lib\site-packages\pandas\core\sorting.py:391, in nargsort(items, kind, ascending, na_position, key, mask)
#     388     mask = np.asarray(isna(items))  # TODO: does this exclude MultiIndex too?
#     390 if is_extension_array_dtype(items):
# --> 391     return items.argsort(ascending=ascending, kind=kind, na_position=na_position)
#     392 else:
#     393     items = np.asanyarray(items)
#
# File c:\Python\Python39\lib\site-packages\pandas\core\arrays\base.py:628, in ExtensionArray.argsort(self, ascending, kind, na_position, *args, **kwargs)
#     625 ascending = nv.validate_argsort_with_ascending(ascending, args, kwargs)
#     627 values = self._values_for_argsort()
# --> 628 return nargsort(
#     629     values,
#     630     kind=kind,
#     631     ascending=ascending,
#     632     na_position=na_position,
#     633     mask=np.asarray(self.isna()),
#     634 )
#
# File c:\Python\Python39\lib\site-packages\pandas\core\sorting.py:403, in nargsort(items, kind, ascending, na_position, key, mask)
#     401     non_nans = non_nans[::-1]
#     402     non_nan_idx = non_nan_idx[::-1]
# --> 403 indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     404 if not ascending:
#     405     indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'str' and 'Timestamp'
